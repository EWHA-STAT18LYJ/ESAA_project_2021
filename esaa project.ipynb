# %%
import os
import pandas as pd 
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
import ast 
from ast import literal_eval

# %%
path = "C:\\Users\\user\\Desktop\\ESAA 프로젝트"
os.chdir(path)

# %%
data = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\user\.conda\envs\test\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.value_counts(data["adult"])
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
data=data[data["adult"]=="False"]

# %%
data[data["adult"]!="False"]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
pd.value_counts(data["adult"])
# Out:
# False    45454
# Name: adult, dtype: int64

# %% [markdown]
# ## 2. belongs_to_collection
# collection이 있는 관측치는 collection name 만 뽑아서 저장

# %%
data["belongs_to_collection"].describe()
# Out:
# count                                                  4491
# unique                                                 1695
# top       {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# freq                                                     29
# Name: belongs_to_collection, dtype: object

# %%
data["belongs_to_collection"].notnull()
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45454, dtype: bool

# %%
data["belongs_to_collection"]
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45454, dtype: object

# %%
type(data["belongs_to_collection"][0])
# Out:
# str

# %%
type(data["belongs_to_collection"][1])
# Out:
# float

# %%
collection=[]
for string in data["belongs_to_collection"]:
    if type(string)==float:
        collection.append(float("Nan"))
    else:
        col_dict=eval(string)
        collection.append(col_dict["name"])

# %%
data["belongs_to_collection"]=collection

# %%
data["belongs_to_collection"]
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45454, dtype: object

# %% [markdown]
# ## 3. budget
# type을 float로 변경

# %%
data["budget"].describe()
# Out:
# count     45454
# unique     1223
# top           0
# freq      36565
# Name: budget, dtype: object

# %%
data["budget"]=pd.to_numeric(data["budget"])

# %%
data["budget"].describe()
# Out:
# count    4.545400e+04
# mean     4.225399e+06
# std      1.742576e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.800000e+08
# Name: budget, dtype: float64

# %% [markdown]
# ## 4. genres
# genres name만 포함하는 리스트 형태로 저장

# %%
data["genres"].describe()
# Out:
# count                             45454
# unique                             4066
# top       [{'id': 18, 'name': 'Drama'}]
# freq                               5000
# Name: genres, dtype: object

# %%
data["genres"]
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45454, dtype: object

# %%
data["genres"][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
data["genres"][45464]
# Out:
# '[]'

# %%
eval(data["genres"][0])
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
genres=[]
for string in data["genres"]:
    genres_list=eval(string)
    if len(genres_list)==0:
        genres.append(float("Nan"))
    else:
        genres2=[]
        for genres_dict in genres_list:
            genres_name=genres_dict["name"]
            genres2.append(genres_name)
        genres.append(genres2)

# %%
data["genres"]=genres

# %%
data["genres"]
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                             NaN
# 45465                             NaN
# Name: genres, Length: 45454, dtype: object

# %% [markdown]
# ## 5. homepage
# 변수 삭제

# %%
del data["homepage"]

# %% [markdown]
# ## 6. id
# type를 object에서 int로 변경 후 같은 값을 갖는 관측치는 하나만 남겨놓고 삭제

# %%
data["id"].describe()
# Out:
# count      45454
# unique     45424
# top       141971
# freq           3
# Name: id, dtype: object

# %%
data["id"]=pd.to_numeric(data["id"],errors='coerce')

# %%
pd.value_counts(data["id"])
# Out:
# 141971    3
# 22649     2
# 12600     2
# 109962    2
# 14788     2
#          ..
# 376934    1
# 86751     1
# 19164     1
# 29403     1
# 276895    1
# Name: id, Length: 45424, dtype: int64

# %%
data[data["id"]==141971]
# Out:
#        adult belongs_to_collection  budget               genres      id  \
# 13261  False                   NaN       0  [Thriller, Mystery]  141971
# 13375  False                   NaN       0  [Thriller, Mystery]  141971
# 16764  False                   NaN       0  [Thriller, Mystery]  141971
#
#          imdb_id original_language original_title  \
# 13261  tt1180333                fi       Blackout
# 13375  tt1180333                fi       Blackout
# 16764  tt1180333                fi       Blackout
#
#                                                 overview popularity  ...  \
# 13261  Recovering from a nail gun shot to the head an...   0.411949  ...
# 13375  Recovering from a nail gun shot to the head an...   0.411949  ...
# 16764  Recovering from a nail gun shot to the head an...   0.411949  ...
#
#       release_date revenue runtime                        spoken_languages  \
# 13261   2008-12-26     0.0   108.0  [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 13375   2008-12-26     0.0   108.0  [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 16764   2008-12-26     0.0   108.0  [{'iso_639_1': 'fi', 'name': 'suomi'}]
#
#          status                                            tagline     title  \
# 13261  Released  Which one is the first to return - memory or t...  Blackout
# 13375  Released  Which one is the first to return - memory or t...  Blackout
# 16764  Released  Which one is the first to return - memory or t...  Blackout
#
#        video vote_average vote_count
# 13261  False          6.7        3.0
# 13375  False          6.7        3.0
# 16764  False          6.7        3.0
#
# [3 rows x 23 columns]

# %%
data=data.drop_duplicates(["id"],keep="first")

# %%
pd.value_counts(data["id"])
# Out:
# 2047      1
# 46492     1
# 38264     1
# 327029    1
# 62836     1
#          ..
# 33765     1
# 176867    1
# 376934    1
# 86751     1
# 276895    1
# Name: id, Length: 45424, dtype: int64

# %%
np.sum(data.duplicated(["id"]))
# Out:
# 0

# %% [markdown]
# ## 7. imdb_id
# 제거

# %%
data["imdb_id"].describe()
# Out:
# count         45407
# unique        45407
# top       tt1079980
# freq              1
# Name: imdb_id, dtype: object

# %%
del data["imdb_id"]

# %%
data.head(3)
# Out:
#    adult      belongs_to_collection    budget                        genres  \
# 0  False       Toy Story Collection  30000000   [Animation, Comedy, Family]
# 1  False                        NaN  65000000  [Adventure, Fantasy, Family]
# 2  False  Grumpy Old Men Collection         0             [Romance, Comedy]
#
#       id original_language    original_title  \
# 0    862                en         Toy Story
# 1   8844                en           Jumanji
# 2  15602                en  Grumpier Old Men
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...    21.9469
# 1  When siblings Judy and Peter discover an encha...    17.0155
# 2  A family wedding reignites the ancient feud be...    11.7129
#
#                         poster_path  ... release_date      revenue runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...   1995-10-30  373554033.0    81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...   1995-12-15  262797249.0   104.0
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 22 columns]

# %% [markdown]
# ## 8. original_language
# 모든 변수 전처리가 끝난 후에 영어 영화만 따로 모은 데이터 추출 예정
# Nan인 것들은 뒤에 spoken_language 변수 정리할 때 다시 정리

# %%
data["original_language"].describe()
# Out:
# count     45413
# unique       89
# top          en
# freq      32246
# Name: original_language, dtype: object

# %%
pd.value_counts(data["original_language"])
# Out:
# en    32246
# fr     2436
# it     1528
# ja     1347
# de     1079
#       ...
# la        1
# ay        1
# qu        1
# uz        1
# lb        1
# Name: original_language, Length: 89, dtype: int64

# %%
np.sum(pd.isnull(data["original_language"]))
# Out:
# 11

# %%
data[pd.isnull(data["original_language"])==True]
# Out:
#        adult belongs_to_collection  budget                         genres  \
# 19574  False                   NaN       0                  [Documentary]
# 21602  False                   NaN       0               [Romance, Drama]
# 22832  False                   NaN       0                 [War, Western]
# 32141  False                   NaN       0                       [Comedy]
# 37407  False                   NaN       0                    [Animation]
# 41047  False                   NaN       0                  [Documentary]
# 41872  False                   NaN       0                  [Documentary]
# 44057  False                   NaN       0                        [Drama]
# 44410  False                   NaN       0       [Animation, Documentary]
# 44576  False                   NaN       0                            NaN
# 44655  False                   NaN       0  [Action, War, Drama, History]
#
#            id original_language              original_title  \
# 19574  283101               NaN     Shadowing the Third Man
# 21602  103902               NaN              Unfinished Sky
# 22832  359195               NaN             13 Fighting Men
# 32141  147050               NaN                   Lambchops
# 37407  257095               NaN                      Bajaja
# 41047  332742               NaN              Song of Lahore
# 41872  144410               NaN  Annabelle Serpentine Dance
# 44057  380438               NaN       Lettre d'une inconnue
# 44410  381096               NaN                        Garn
# 44576  381525               NaN                      WiNWiN
# 44655  104473               NaN       La prise de Tournavos
#
#                                                 overview popularity  \
# 19574  Documentary about the production of The Third ...   0.017007
# 21602  An Outback farmer takes in an Afghani woman wh...   0.359818
# 22832  A group of Union Army soldiers is charged with...   0.070647
# 32141  George and Gracie enter an elegant drawing roo...   0.073418
# 37407  The first fairy tale transformed into a full-l...   0.036841
# 41047  Until the late 1970s, the Pakistani city of La...   0.373688
# 41872  Two dancers perform in succession facing a sta...    1.58434
# 44057                                                NaN   0.001283
# 44410  The traditional crafts of crochet and knitting...   0.067624
# 44576  American investment fund buys Austrian compani...   0.030766
# 44655  Three military men, seen inside a fortificatio...   0.471325
#
#                             poster_path  ... release_date revenue runtime  \
# 19574  /xT9csxMKYbizRQgvNzCXJ67R7er.jpg  ...   2004-10-11     0.0    95.0
# 21602  /vfaJuZF0ocVwBEDYZhoULGuVxrz.jpg  ...   2007-08-04     0.0    94.0
# 22832  /q5ADXvvzYtAOyrReIg1HckdPj62.jpg  ...   1960-03-31     0.0    69.0
# 32141  /upQByEwY58sHWdL3RZm7kmRc44s.jpg  ...   1929-10-31     0.0     8.0
# 37407  /12wf2EkrPGxNzRbNyoau8GIFp3M.jpg  ...   1950-01-26     0.0    87.0
# 41047  /6iJqscs2xQLKKvrTCWmlHd9rf3W.jpg  ...   2015-11-13     0.0    82.0
# 41872  /l7Lzvah6PL6vdMF5p0elKiyYqp9.jpg  ...   1895-04-01     0.0     1.0
# 44057  /gk32ZWTYgfTXctEyCDAWeMcxo7X.jpg  ...   2001-01-01     0.0     0.0
# 44410  /olEOCEGTW15WBPC0UnmLjokrmNF.jpg  ...   2016-03-12     0.0    76.0
# 44576  /pErCRQoc3nt8lCsExd3fFYgyBox.jpg  ...   2016-01-27     0.0    84.0
# 44655  /4VmQBE9qBRxCE3gHtSAa5AUsURq.jpg  ...   1897-01-01     0.0     1.0
#
#                                         spoken_languages    status tagline  \
# 19574  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released     NaN
# 21602           [{'iso_639_1': 'en', 'name': 'English'}]  Released     NaN
# 22832           [{'iso_639_1': 'en', 'name': 'English'}]  Released     NaN
# 32141           [{'iso_639_1': 'en', 'name': 'English'}]  Released     NaN
# 37407             [{'iso_639_1': 'cs', 'name': 'Český'}]  Released     NaN
# 41047  [{'iso_639_1': 'ur', 'name': 'اردو'}, {'iso_63...  Released     NaN
# 41872       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released     NaN
# 44057          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released     NaN
# 44410  [{'iso_639_1': 'sv', 'name': 'svenska'}, {'iso...  Released     NaN
# 44576  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released     NaN
# 44655       [{'iso_639_1': 'xx', 'name': 'No Language'}]   Rumored     NaN
#
#                             title  video vote_average vote_count
# 19574     Shadowing the Third Man  False          0.0        0.0
# 21602              Unfinished Sky  False          6.4        8.0
# 22832             13 Fighting Men  False          0.0        0.0
# 32141                   Lambchops  False          6.5        2.0
# 37407               Prince Bayaya  False          5.0        1.0
# 41047              Song of Lahore  False          6.5        2.0
# 41872  Annabelle Serpentine Dance  False          5.7       20.0
# 44057       Lettre d'une inconnue  False          0.0        0.0
# 44410                        Yarn  False          0.0        0.0
# 44576                      WiNWiN  False          0.0        0.0
# 44655  The Surrender of Tournavos  False          4.6        5.0
#
# [11 rows x 22 columns]

# %% [markdown]
# ## 9.  original_title

# %%
data["original_title"].describe()
# Out:
# count      45424
# unique     43363
# top       Hamlet
# freq           8
# Name: original_title, dtype: object

# %%
pd.value_counts(data["original_title"])
# Out:
# Hamlet                         8
# Alice in Wonderland            8
# Macbeth                        7
# A Christmas Carol              7
# Cinderella                     7
#                               ..
# The Net 2.0                    1
# The Little Kidnappers          1
# Dude Bro Party Massacre III    1
# Real Life                      1
# The Evening Star               1
# Name: original_title, Length: 43363, dtype: int64

# %%
data[data["original_title"]=="Alice in Wonderland"]
# Out:
#        adult           belongs_to_collection     budget  \
# 1003   False                             NaN    3000000
# 9665   False                             NaN   21000000
# 11887  False                             NaN   14000000
# 14892  False  Alice in Wonderland Collection  200000000
# 15868  False                             NaN          0
# 26894  False                             NaN          0
# 32901  False                             NaN          0
# 39530  False                             NaN          0
#
#                                                   genres     id  \
# 1003             [Animation, Adventure, Family, Fantasy]  12092
# 9665                                   [Fantasy, Family]  30923
# 11887                                  [Family, Fantasy]  34573
# 14892                       [Family, Fantasy, Adventure]  12155
# 15868  [Action, Adventure, Family, Fantasy, Science F...  25694
# 26894                 [Family, Fantasy, Science Fiction]  35109
# 32901                                  [Family, Fantasy]  87300
# 39530                                          [Fantasy]  41278
#
#       original_language       original_title  \
# 1003                 en  Alice in Wonderland
# 9665                 en  Alice in Wonderland
# 11887                en  Alice in Wonderland
# 14892                en  Alice in Wonderland
# 15868                en  Alice in Wonderland
# 26894                en  Alice in Wonderland
# 32901                en  Alice in Wonderland
# 39530                en  Alice in Wonderland
#
#                                                 overview popularity  \
# 1003   On a golden afternoon, young Alice follows a W...    16.4889
# 9665   Alice follows a white rabbit down a rabbit-hol...     8.6143
# 11887  Classic tale of a girl named Alice who follows...    3.79413
# 14892  Alice, an unpretentious and individual 19-year...    17.2851
# 15868  On a boring winter afternoon, Alice dreams, th...    1.50435
# 26894  Alice in Wonderland (1966) is a BBC television...    1.71604
# 32901  A German adaptation of the classic Lewis Carro...   0.140291
# 39530  This is the first movie version of the famous ...   0.708323
#
#                             poster_path  ... release_date       revenue  \
# 1003   /9gJa2B6M8jt85aDkb0MF98MLZ9T.jpg  ...   1951-07-03  5.720000e+08
# 9665   /c53p3QRI0BNx7KE1zH8fXoWq4sM.jpg  ...   1999-02-28  0.000000e+00
# 11887  /1jlw8lSaLetDP4XqioTgK6R38Lt.jpg  ...   1985-12-09  0.000000e+00
# 14892  /pvEE5EN5N1yjmHmldfL4aJWm56l.jpg  ...   2010-03-03  1.025491e+09
# 15868  /hA536GMozYb9zbMjo2NqESniveU.jpg  ...   1933-12-22  0.000000e+00
# 26894  /dWnbHEZ31kMOx8cnN7IvG3fBpwp.jpg  ...   1966-12-26  0.000000e+00
# 32901  /9YJqY2MWOUzy60iMhniOF4NEZRs.jpg  ...   1915-01-15  0.000000e+00
# 39530  /rATc0e78ORRmJyvgqAywkejdgqh.jpg  ...   1903-10-17  0.000000e+00
#
#       runtime                              spoken_languages    status  \
# 1003     75.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9665    150.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11887   187.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14892   108.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15868    76.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 26894    72.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 32901    52.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 39530     9.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
#
#                                         tagline                title  video  \
# 1003    A world of wonders in One Great Picture  Alice in Wonderland  False
# 9665            A Masterpiece of Imagination...  Alice in Wonderland  False
# 11887                                       NaN  Alice in Wonderland  False
# 14892  You're invited to a very important date.  Alice in Wonderland  False
# 15868   The Entertainment Miracle Of All Times!  Alice in Wonderland  False
# 26894                                       NaN  Alice in Wonderland  False
# 32901                                       NaN  Alice in Wonderland  False
# 39530                                       NaN  Alice in Wonderland  False
#
#       vote_average vote_count
# 1003           7.0     1557.0
# 9665           6.1       71.0
# 11887          6.3       15.0
# 14892          6.4     4773.0
# 15868          5.4        8.0
# 26894          6.9        8.0
# 32901          5.5        2.0
# 39530          6.1       20.0
#
# [8 rows x 22 columns]

# %% [markdown]
# ## 10. overview

# %%
data["overview"].describe()
# Out:
# count                  44470
# unique                 44297
# top       No overview found.
# freq                     133
# Name: overview, dtype: object

# %%
data["overview"].value_counts()
# Out:
# No overview found.                                                                                                                                                                                                                                                                                                                                                                                                                                   133
# No Overview                                                                                                                                                                                                                                                                                                                                                                                                                                            7
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        5
# No movie overview available.                                                                                                                                                                                                                                                                                                                                                                                                                           3
# Adaptation of the Jane Austen novel.                                                                                                                                                                                                                                                                                                                                                                                                                   3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Filmed at the Celebrity Theatre in Phoenix, AZ on February 15th and 16th, 2013, Oh My God is Louis C.K.'s fifth stand-up special, his first for HBO since 2007's Shameless, and his first since winning a Emmy Award for writing on his acclaimed show on FX, Louie.  Performed in the round in front of a live audience, he discusses such topics as the food chain, animals, divorce, strange anecdotes, broken morality, murder and mortality.      1
# Wisecracking reporter Carl Kolchak investigates a string of gruesome murders in Las Vegas. It seems that each victim has been bitten in the neck and drained of all their blood. Kolchak is sure that it is a vampire. He's hot on the trail, but nobody believes him. His editor thinks he's nuts and the police think he's a hindrance in the investigation, so Kolchak takes matters into his own hand.                                             1
# Filmmaker Christopher Browne documents the mission of a group of middle-aged bowlers as they attempt to revitalize the sport and get the television-watching public interested in it again.                                                                                                                                                                                                                                                            1
# A young psychiatric intern unearths secrets about the mental health facility in which he works.                                                                                                                                                                                                                                                                                                                                                        1
# Eight close friends soak up their last day of summer together on the beach before parting ways for college.                                                                                                                                                                                                                                                                                                                                            1
# Name: overview, Length: 44297, dtype: int64

# %%
text_counts = data["overview"].value_counts()
text_list = text_counts[text_counts > 1].index.tolist()

# %%
overview_list=[]
for overview in data["overview"]:
    if overview=="No overview found.":
        overview_list.append("")
    elif overview=="No Overview":
        overview_list.append("")
    elif overview==" ":
        overview_list.append("")
    elif overview=="No movie overview available.":
        overview_list.append("")
    else:
        overview_list.append(overview)

# %%
data["overview"]=overview_list

# %% [markdown]
# ## 11. popularity
# type을 object에서 numeric으로 변환

# %%
data["popularity"].describe()
# Out:
# count     45421
# unique    44149
# top         0.0
# freq         34
# Name: popularity, dtype: object

# %%
data["popularity"]=pd.to_numeric(data["popularity"],errors='coerce')

# %%
data["popularity"].describe()
# Out:
# count    45421.000000
# mean         2.921493
# std          6.007204
# min          0.000000
# 25%          0.385850
# 50%          1.127098
# 75%          3.678394
# max        547.488298
# Name: popularity, dtype: float64

# %%
del data["poster_path"]

# %% [markdown]
# 13. production_companies

# %%
data["production_companies"].describe()
# Out:
# count     45421
# unique    22704
# top          []
# freq      11865
# Name: production_companies, dtype: object

# %%
companies=[]
for string in data["production_companies"]:
    if type(string)==float:
        companies.append(float("Nan"))
    else:
        companies_list=eval(string)
        if len(companies_list)==0:
            companies.append(float("Nan"))
        else:
            companies2=[]
            for companies_dict in companies_list:
                companies_name=companies_dict["name"]
                companies2.append(companies_name)
            companies.append(companies2)

# %%
data["production_companies"]=companies

# %% [markdown]
# ## 14. production_countries

# %%
data["production_countries"].describe()
# Out:
# count                                                 45421
# unique                                                 2390
# top       [{'iso_3166_1': 'US', 'name': 'United States o...
# freq                                                  17838
# Name: production_countries, dtype: object

# %%
data["production_countries"]
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45424, dtype: object

# %%
countries=[]
for string in data["production_countries"]:
    if type(string)==float:
        countries.append(float("Nan"))
    else:
        countries_list=eval(string)
        if len(countries_list)==0:
            countries.append(float("Nan"))
        else:
            countries2=[]
            for countries_dict in countries_list:
                countries_name=countries_dict["name"]
                countries2.append(countries_name)
            countries.append(countries2)

# %%
data["production_countries"]=countries

# %%
data["production_countries"]
# Out:
# 0        [United States of America]
# 1        [United States of America]
# 2        [United States of America]
# 3        [United States of America]
# 4        [United States of America]
#                     ...
# 45461                        [Iran]
# 45462                 [Philippines]
# 45463    [United States of America]
# 45464                      [Russia]
# 45465              [United Kingdom]
# Name: production_countries, Length: 45424, dtype: object

# %% [markdown]
# ## 15. release_date
# datetime으로 변환

# %%
data["release_date"].describe()
# Out:
# count          45338
# unique         17329
# top       2008-01-01
# freq             136
# Name: release_date, dtype: object

# %%
from datetime import datetime

# %%
date=[]
for string in data["release_date"]:
    if type(string)!=str:
        date.append(float("Nan"))
    else:
        date.append(datetime.strptime(string, "%Y-%m-%d"))

# %%
data["release_date"]=date

# %%
data["release_date"]
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45424, dtype: datetime64[ns]

# %% [markdown]
# ## 16. revenue

# %%
data["revenue"].describe()
# Out:
# count    4.542100e+04
# mean     1.121511e+07
# std      6.435831e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.787965e+09
# Name: revenue, dtype: float64

# %%
np.sum(data["revenue"].isnull())
# Out:
# 3

# %%
data[pd.isnull(data["revenue"])==True]
#얘네는 Nan이 여러개라서 없애는게 나을 것 같다고 함
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ## 17. runtime

# %%
data["runtime"].describe()
# Out:
# count    45164.000000
# mean        94.129196
# std         38.413954
# min          0.000000
# 25%         85.000000
# 50%         95.000000
# 75%        107.000000
# max       1256.000000
# Name: runtime, dtype: float64

# %%
np.sum(pd.isnull(data["runtime"]))
# Out:
# 260

# %%
data[pd.isnull(data["runtime"])==True]
# Nan값이 많아서 그냥 둠. 0으로 대체하면 나중에 분석할 때 값이 달라질 것 같다고 함
# Out:
#        adult belongs_to_collection  budget          genres      id  \
# 634    False                   NaN       0        [Comedy]  287305
# 635    False                   NaN       0        [Comedy]  339428
# 644    False                   NaN       0         [Drama]  278978
# 802    False                   NaN       0         [Drama]  282919
# 863    False                   NaN       0      [Thriller]  253632
# ...      ...                   ...     ...             ...     ...
# 45246  False                   NaN       0        [Comedy]  231216
# 45310  False                   NaN       0             NaN  418757
# 45313  False                   NaN       0         [Drama]  369444
# 45377  False                   NaN       0     [Adventure]  317389
# 45410  False                   NaN       0  [Drama, Crime]  449131
#
#       original_language                  original_title overview  popularity  \
# 634                  de  Peanuts – Die Bank zahlt alles      NaN    0.066123
# 635                  de                   Happy Weekend      NaN    0.002229
# 644                  de       Und keiner weint mir nach      NaN    0.439989
# 802                  de                       Diebinnen      NaN    0.106345
# 863                  fr                     Baton Rouge      NaN    0.437895
# ...                 ...                             ...      ...         ...
# 45246                de                 Villa Henriette      NaN    0.002513
# 45310                pl         Między nami dobrze jest      NaN    0.030803
# 45313                pl                 Ostatni dzwonek      NaN    0.000102
# 45377                es   Simbad e il califfo di Bagdad      NaN    0.006352
# 45410                ru                           Aprel      NaN    0.008903
#
#                  production_companies  ... release_date  revenue  runtime  \
# 634    [Westdeutscher Rundfunk (WDR)]  ...   1996-03-21      0.0      NaN
# 635         [Senator Film Produktion]  ...   1996-03-14  65335.0      NaN
# 644                               NaN  ...   1996-02-29      0.0      NaN
# 802                               NaN  ...   1996-06-20      0.0      NaN
# 863                               NaN  ...   1988-10-08      0.0      NaN
# ...                               ...  ...          ...      ...      ...
# 45246                             NaN  ...   2004-12-02      0.0      NaN
# 45310                             NaN  ...   2014-08-01      0.0      NaN
# 45313                             NaN  ...   1989-10-27      0.0      NaN
# 45377   [Roas Produzioni, Buton Film]  ...   1973-07-22      0.0      NaN
# 45410                             NaN  ...          NaT      0.0      NaN
#
#                                 spoken_languages    status tagline  \
# 634                                           []  Released     NaN
# 635     [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released     NaN
# 644     [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released     NaN
# 802                                           []  Released     NaN
# 863                                           []  Released     NaN
# ...                                          ...       ...     ...
# 45246   [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released     NaN
# 45310                                         []  Released     NaN
# 45313                                         []  Released     NaN
# 45377  [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released     NaN
# 45410                                         []  Released     NaN
#
#                                 title  video vote_average  vote_count
# 634    Peanuts – Die Bank zahlt alles  False          4.0         1.0
# 635                     Happy Weekend  False          0.0         0.0
# 644         Und keiner weint mir nach  False          0.0         0.0
# 802                         Diebinnen  False          4.0         1.0
# 863                       Baton Rouge  False          0.0         0.0
# ...                               ...    ...          ...         ...
# 45246                 Villa Henriette  False          0.0         0.0
# 45310         Między nami dobrze jest  False          0.0         0.0
# 45313                 Ostatni dzwonek  False          0.0         0.0
# 45377   Simbad e il califfo di Bagdad  False          0.0         0.0
# 45410                           Aprel  False          6.0         1.0
#
# [260 rows x 21 columns]

# %% [markdown]
# ## 18. spoken_languages

# %%
data["spoken_languages"].describe()
# Out:
# count                                        45421
# unique                                        1931
# top       [{'iso_639_1': 'en', 'name': 'English'}]
# freq                                         22375
# Name: spoken_languages, dtype: object

# %%
np.sum(pd.isnull(data["spoken_languages"]))
# Out:
# 3

# %%
data[pd.isnull(data["spoken_languages"])==True]
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %%
language=[]
for string in data["spoken_languages"]:
    if type(string)!=str:
        language.append(float("Nan"))
    else:
        language_list=eval(string)
        if len(language_list)==0:
            language.append(float("Nan"))
        else:
            language2=[]
            for language_dict in language_list:
                language_name=language_dict["name"]
                language2.append(language_name)
            language.append(language2)

# %%
data["spoken_languages"]=language

# %%
data["spoken_languages"]
# Out:
# 0                  [English]
# 1        [English, Français]
# 2                  [English]
# 3                  [English]
# 4                  [English]
#                 ...
# 45461                [فارسی]
# 45462                     []
# 45463              [English]
# 45464                    NaN
# 45465              [English]
# Name: spoken_languages, Length: 45424, dtype: object

# %%
for string in data["spoken_languages"]:
    if type(string)==list:
        for lan in string:
            if lan=="":
                string.remove("")

# %%
data["spoken_languages"]
# Out:
# 0                  [English]
# 1        [English, Français]
# 2                  [English]
# 3                  [English]
# 4                  [English]
#                 ...
# 45461                [فارسی]
# 45462                     []
# 45463              [English]
# 45464                    NaN
# 45465              [English]
# Name: spoken_languages, Length: 45424, dtype: object

# %% [markdown]
# ## 19. status

# %%
data["status"].describe()
# Out:
# count        45340
# unique           6
# top       Released
# freq         44977
# Name: status, dtype: object

# %%
pd.value_counts(data["status"])
# Out:
# Released           44977
# Rumored              229
# Post Production       98
# In Production         19
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
np.sum(pd.isnull(data["status"]))
# Out:
# 84

# %%
# Nan인 애들 중에 popularity나 revenue가 0이 아닌 것들은 개봉한 것으로 생각할 수 있으니, released로 채운다고 함
data[pd.isnull(data["status"])==True]
# Out:
#        adult belongs_to_collection  budget                     genres      id  \
# 189    False                   NaN       0              [Documentary]   56088
# 767    False                   NaN       0              [Documentary]   52059
# 1384   False                   NaN       0                   [Comedy]   40506
# 2140   False                   NaN       0                        NaN   77314
# 3460   False                   NaN       0                    [Drama]   94214
# ...      ...                   ...     ...                        ...     ...
# 44377  False                   NaN       0                        NaN   39827
# 45067  False                   NaN       0  [Drama, Romance, Foreign]   49492
# 45090  False                   NaN       0                        NaN  128268
# 45159  False                   NaN       0                        NaN   41811
# 45442  False                   NaN       0                        NaN   44330
#
#       original_language                                 original_title  \
# 189                  en                                       The Show
# 767                  en                     The Gate of Heavenly Peace
# 1384                 en                              Meet Wally Sparks
# 2140                 fr                     The Cabinet of Dr. Ramirez
# 3460                 en                     Jails, Hospitals & Hip-Hop
# ...                 ...                                            ...
# 44377                en           The Who: Thirty Years of Maximum R&B
# 45067                en                          Jogwa - The Awakening
# 45090                en  Veruschka - Die Inszenierung (m)eines Körpers
# 45159                en                                         Eating
# 45442                en                           Le tripot clandestin
#
#                                                 overview  popularity  \
# 189    A documentary about the culture of hip-hop. Th...    0.159596
# 767    The Gate of Heavenly Peace is a feature-length...    0.107050
# 1384   Wally Sparks is a tabloid TV show reporter who...    0.576741
# 2140                                                 NaN    0.037500
# 3460   Jails, Hospitals &amp; Hip-Hop is a cinematic ...    0.009057
# ...                                                  ...         ...
# 44377              A celebration of 30 years of The Who.    0.014260
# 45067  Jogwa actually means alms given to a person, u...    0.004990
# 45090         Documentary about Veruschka von Lehndorff.    0.056298
# 45159  At a spacious house in Los Angeles, Helene is ...    0.000002
# 45442  A combination gambling den and bawdy house is ...    0.219260
#
#       production_companies  ... release_date revenue  runtime  \
# 189                    NaN  ...   1995-08-25     0.0     93.0
# 767                    NaN  ...   1995-01-01     0.0    180.0
# 1384                   NaN  ...   1997-01-01     0.0    105.0
# 2140                   NaN  ...   1991-12-04     0.0      NaN
# 3460                   NaN  ...          NaT    10.0     90.0
# ...                    ...  ...          ...     ...      ...
# 44377                  NaN  ...   1994-08-15     0.0    155.0
# 45067                  NaN  ...   2009-09-25     0.0     92.0
# 45090                  NaN  ...   2005-09-30     0.0     52.0
# 45159                  NaN  ...   1990-11-30     0.0    110.0
# 45442                  NaN  ...   1905-01-01     0.0      3.0
#
#           spoken_languages status  \
# 189                    NaN    NaN
# 767                    NaN    NaN
# 1384             [English]    NaN
# 2140                   NaN    NaN
# 3460                   NaN    NaN
# ...                    ...    ...
# 44377                  NaN    NaN
# 45067                  NaN    NaN
# 45090  [Deutsch, Français]    NaN
# 45159            [English]    NaN
# 45442                  NaN    NaN
#
#                                                  tagline  \
# 189        What Happens On Stage Is Only Half The Story!
# 767                                                  NaN
# 1384                                                 NaN
# 2140                                                 NaN
# 3460   three worlds / two million voices / one genera...
# ...                                                  ...
# 44377                                                NaN
# 45067                                      The Awakening
# 45090                                                NaN
# 45159                                                NaN
# 45442                                                NaN
#
#                                       title  video vote_average  vote_count
# 189                                The Show  False          5.3         2.0
# 767              The Gate of Heavenly Peace  False          6.7         3.0
# 1384                      Meet Wally Sparks  False          5.3        10.0
# 2140             The Cabinet of Dr. Ramirez  False          0.0         0.0
# 3460             Jails, Hospitals & Hip-Hop  False          0.0         0.0
# ...                                     ...    ...          ...         ...
# 44377  The Who: Thirty Years of Maximum R&B  False          0.0         0.0
# 45067                 Jogwa - The Awakening  False          0.0         0.0
# 45090      Veruschka: A Life for the Camera  False          6.0         1.0
# 45159                                Eating  False          0.0         0.0
# 45442       The Scheming Gambler's Paradise  False          5.0         3.0
#
# [84 rows x 21 columns]

# %% [markdown]
# ## 20. tagline

# %%
data["tagline"].describe()
# Out:
# count                      20395
# unique                     20277
# top       Based on a true story.
# freq                           7
# Name: tagline, dtype: object

# %%
pd.value_counts(data["tagline"])
# Out:
# Based on a true story.                                                                                                                7
# -                                                                                                                                     4
# Be careful what you wish for.                                                                                                         4
# Trust no one.                                                                                                                         4
# Documentary                                                                                                                           3
#                                                                                                                                      ..
# The world will never be the same, once you've seen it through the eyes of Forrest Gump.                                               1
# The story of hot-blooded Maria... who always gets her man, after man, after man!                                                      1
# All The Spectacle Of Heathen Idolatry, Human Sacrifice, Pagan Revels - All The Beauty Of One Of The Bible's Timeless Love Stories!    1
# Lights. Camera. Aggravation.                                                                                                          1
# They had nothing... and tried to find their dream.                                                                                    1
# Name: tagline, Length: 20277, dtype: int64

# %%
np.sum(pd.isnull(data["tagline"]))
# Out:
# 25029

# %%
data[pd.isnull(data["tagline"])==True]
# Out:
#        adult belongs_to_collection    budget                       genres  \
# 0      False  Toy Story Collection  30000000  [Animation, Comedy, Family]
# 11     False                   NaN         0             [Comedy, Horror]
# 27     False                   NaN         0             [Drama, Romance]
# 32     False                   NaN         0         [Romance, Adventure]
# 35     False                   NaN  11000000                      [Drama]
# ...      ...                   ...       ...                          ...
# 45459  False                   NaN         0            [Science Fiction]
# 45460  False                   NaN         0     [Drama, Action, Romance]
# 45462  False                   NaN         0                      [Drama]
# 45464  False                   NaN         0                          NaN
# 45465  False                   NaN         0                          NaN
#
#            id original_language                    original_title  \
# 0         862                en                         Toy Story
# 11      12110                en       Dracula: Dead and Loving It
# 27      17015                en                        Persuasion
# 32      78802                fr  Guillaumet, les ailes du courage
# 35        687                en                  Dead Man Walking
# ...       ...               ...                               ...
# 45459  222848                en                   Caged Heat 3000
# 45460   30840                en                        Robin Hood
# 45462  111109                tl               Siglo ng Pagluluwal
# 45464  227506                en               Satana likuyushchiy
# 45465  461257                en                          Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 11     When a lawyer shows up at the vampire's doorst...    5.430331
# 27     This film adaptation of Jane Austen's last nov...    2.228434
# 32                                                   NaN    0.745542
# 35     A justice drama based on a true story about a ...    6.891317
# ...                                                  ...         ...
# 45459  It's the year 3000 AD. The world's most danger...    0.661558
# 45460  Yet another version of the classic epic, with ...    5.683753
# 45462  An artist struggles to finish his work while a...    0.178241
# 45464  In a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                                     production_companies  ... release_date  \
# 0                              [Pixar Animation Studios]  ...   1995-10-30
# 11     [Columbia Pictures, Castle Rock Entertainment,...  ...   1995-12-22
# 27                                           [BBC Films]  ...   1995-09-27
# 32                                [Iwerks Entertainment]  ...   1996-09-18
# 35     [Havoc, PolyGram Filmed Entertainment, Working...  ...   1995-12-29
# ...                                                  ...  ...          ...
# 45459                            [Concorde-New Horizons]  ...   1995-01-01
# 45460  [Westdeutscher Rundfunk (WDR), Working Title F...  ...   1991-05-13
# 45462                                      [Sine Olivia]  ...   2011-11-17
# 45464                                        [Yermoliev]  ...   1917-10-21
# 45465                                                NaN  ...   2017-06-09
#
#            revenue  runtime    spoken_languages    status tagline  \
# 0      373554033.0     81.0           [English]  Released     NaN
# 11             0.0     88.0  [English, Deutsch]  Released     NaN
# 27             0.0    104.0           [English]  Released     NaN
# 32             0.0     50.0           [English]  Released     NaN
# 35      39363635.0    122.0           [English]  Released     NaN
# ...            ...      ...                 ...       ...     ...
# 45459          0.0     85.0           [English]  Released     NaN
# 45460          0.0    104.0           [English]  Released     NaN
# 45462          0.0    360.0                  []  Released     NaN
# 45464          0.0     87.0                 NaN  Released     NaN
# 45465          0.0     75.0           [English]  Released     NaN
#
#                              title  video vote_average  vote_count
# 0                        Toy Story  False          7.7      5415.0
# 11     Dracula: Dead and Loving It  False          5.7       210.0
# 27                      Persuasion  False          7.4        36.0
# 32                Wings of Courage  False          6.8         4.0
# 35                Dead Man Walking  False          7.3       350.0
# ...                            ...    ...          ...         ...
# 45459              Caged Heat 3000  False          3.5         1.0
# 45460                   Robin Hood  False          5.7        26.0
# 45462          Century of Birthing  False          9.0         3.0
# 45464             Satan Triumphant  False          0.0         0.0
# 45465                     Queerama  False          0.0         0.0
#
# [25029 rows x 21 columns]

# %% [markdown]
# ## 21. title

# %%
data["title"].describe()
# Out:
# count          45421
# unique         42269
# top       Cinderella
# freq              11
# Name: title, dtype: object

# %%
pd.value_counts(data["title"])
# Out:
# Cinderella                 11
# Hamlet                      9
# Alice in Wonderland         9
# Beauty and the Beast        8
# Les Misérables              8
#                            ..
# India Song                  1
# The Youngest Profession     1
# Surf's Up                   1
# Archipelago                 1
# The Evening Star            1
# Name: title, Length: 42269, dtype: int64

# %%
np.sum(pd.isnull(data["title"]))
# Out:
# 3

# %%
data[pd.isnull(data["title"])==True]
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ## 22. video
# >> 변수가 뭘 의미하는지 모르겠어서 그냥 버리는게 나을 것 같긴 한데 우선 그냥 냅둠

# %%
data["video"].describe()
# Out:
# count     45421
# unique        2
# top       False
# freq      45328
# Name: video, dtype: object

# %%
pd.value_counts(data["video"])
# Out:
# False    45328
# True        93
# Name: video, dtype: int64

# %%
np.sum(pd.isnull(data["video"]))
# Out:
# 3

# %%
data[pd.isnull(data["video"])==True]
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %%
data[data["video"]==True]
# Out:
#        adult    belongs_to_collection  budget  \
# 5492   False                      NaN       0
# 11469  False  Loose Change Collection    5000
# 13564  False                      NaN       0
# 14271  False     Love Hina Collection       0
# 14608  False                      NaN       0
# ...      ...                      ...     ...
# 44286  False                      NaN       0
# 44798  False                      NaN       0
# 44861  False                      NaN       0
# 44981  False                      NaN       0
# 45199  False                      NaN       0
#
#                                                   genres      id  \
# 5492   [Action, Adventure, Animation, Comedy, Family,...   15173
# 11469                                      [Documentary]   14277
# 13564                                      [Documentary]  284117
# 14271                [Comedy, Romance, Animation, Music]   44685
# 14608               [Action, Adventure, Family, Fantasy]   35148
# ...                                                  ...     ...
# 44286                        [Action, Animation, Horror]  161337
# 44798               [Animation, Horror, Science Fiction]  425916
# 44861                                                NaN  334795
# 44981                            [Family, Drama, Comedy]  461088
# 45199                                [Comedy, Animation]  279687
#
#       original_language                          original_title  \
# 5492                 en              Jonah: A VeggieTales Movie
# 11469                en               Loose Change: 2nd Edition
# 13564                en                                   Fitna
# 14271                ja              ラブひな 春スペシャル ～キミサクラチルナカレ!!～
# 14608                en  Playmobil: The Secret of Pirate Island
# ...                 ...                                     ...
# 44286                en                 Underworld: Endless War
# 44798                en                           Salad Fingers
# 44861                ru                           Конец Каникул
# 44981                fa                          ۵۰ کیلو آلبالو
# 45199                en            Futurama: The Lost Adventure
#
#                                                 overview  popularity  \
# 5492   Get ready as Bob the Tomato, Larry the Cucumbe...    1.734181
# 11469  What if...September 11th was not a surprise at...    0.651714
# 13564  A short film in which Quran verses are shown a...    0.040068
# 14271  The tests have come, and Keitaro can only hope...    1.785708
# 14608  Ahoy, matey! Your Favorite Playmobil toys have...    0.014168
# ...                                                  ...         ...
# 44286  Underworld: Endless War is a collection of thr...    3.301063
# 44798  The adventures of Salad Fingers, an unspecifie...    0.141367
# 44861  Four music videos of Kino band joined together...    0.000000
# 44981  When the corrupted groom starts shooting in th...    0.034119
# 45199  The cut-scenes from Futurama (2003) (VG), edit...    0.988667
#
#              production_companies  ... release_date revenue  runtime  \
# 5492       [Big Idea Productions]  ...   2002-10-04     0.0     82.0
# 11469  [Polar Film   Medien GmbH]  ...   2006-06-01     0.0    100.0
# 13564                         NaN  ...   2008-03-27     0.0     15.0
# 14271           [TV Tokyo, Xebec]  ...   2001-03-31     0.0     48.0
# 14608                         NaN  ...   2009-10-13     0.0    140.0
# ...                           ...  ...          ...     ...      ...
# 44286                         NaN  ...   2011-10-19     0.0     18.0
# 44798                         NaN  ...          NaT     0.0     52.0
# 44861                         NaN  ...   1986-01-01     0.0     23.0
# 44981                         NaN  ...   2016-03-22     0.0     89.0
# 45199     [The Curiosity Company]  ...   2008-06-24     0.0     30.0
#
#                                         spoken_languages    status  \
# 5492                                    [Český, English]  Released
# 11469                                          [English]  Released
# 13564                              [English, Nederlands]  Released
# 14271                                              [日本語]  Released
# 14608  [Français, English, Norsk, Português, ภาษาไทย,...  Released
# ...                                                  ...       ...
# 44286                                          [English]  Released
# 44798                                          [English]  Released
# 44861                                          [Pусский]  Released
# 44981                                            [فارسی]  Released
# 45199                                          [English]  Released
#
#                                  tagline  \
# 5492       Fresh Fish. Mixed Vegetables.
# 11469      What really happened on 9/11?
# 13564                                NaN
# 14271  Spring break... Love Hina Style!!
# 14608                                NaN
# ...                                  ...
# 44286                                NaN
# 44798                                NaN
# 44861          Victor Tsoy's movie debut
# 44981                                NaN
# 45199                                NaN
#
#                                               title video vote_average  \
# 5492                     Jonah: A VeggieTales Movie  True          6.4
# 11469                     Loose Change: 2nd Edition  True          6.3
# 13564                                         Fitna  True          1.0
# 14271  Love Hina Spring Special - I Wish Your Dream  True          4.7
# 14608        Playmobil: The Secret of Pirate Island  True          0.0
# ...                                             ...   ...          ...
# 44286                       Underworld: Endless War  True          5.6
# 44798                                 Salad Fingers  True          8.5
# 44861                         The End of a Vacation  True          0.0
# 44981                       50 Kilos of Sour Cherry  True          0.0
# 45199                  Futurama: The Lost Adventure  True          7.9
#
#        vote_count
# 5492         22.0
# 11469        16.0
# 13564         1.0
# 14271         3.0
# 14608         0.0
# ...           ...
# 44286        38.0
# 44798         4.0
# 44861         0.0
# 44981         0.0
# 45199        10.0
#
# [93 rows x 21 columns]

# %% [markdown]
# ## 23. vote_average

# %%
data["vote_average"].describe()
# Out:
# count    45421.000000
# mean         5.618665
# std          1.924008
# min          0.000000
# 25%          5.000000
# 50%          6.000000
# 75%          6.800000
# max         10.000000
# Name: vote_average, dtype: float64

# %%
np.sum(pd.isnull(data["vote_average"]))
# Out:
# 3

# %%
data[pd.isnull(data["vote_average"])==True]
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ## 24. vote_count

# %%
data["vote_count"].describe()
# Out:
# count    45421.000000
# mean       109.956210
# std        491.512921
# min          0.000000
# 25%          3.000000
# 50%         10.000000
# 75%         34.000000
# max      14075.000000
# Name: vote_count, dtype: float64

# %%
np.sum(pd.isnull(data["vote_count"]))
# Out:
# 3

# %%
data[pd.isnull(data["vote_count"])==True]
# Out:
#        adult        belongs_to_collection  budget  \
# 19729  False                          NaN       0
# 29502  False  Mardock Scramble Collection       0
# 35586  False                          NaN       0
#
#                                             genres      id original_language  \
# 19729                    [Action, Thriller, Drama]   82663                en
# 29502                 [Animation, Science Fiction]  122662                ja
# 35586  [TV Movie, Action, Horror, Science Fiction]  249260                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        popularity production_companies  ... release_date revenue  runtime  \
# 19729         NaN                  NaN  ...          NaT     NaN      NaN
# 29502         NaN                  NaN  ...          NaT     NaN      NaN
# 35586         NaN                  NaN  ...          NaT     NaN      NaN
#
#        spoken_languages status tagline title video vote_average  vote_count
# 19729               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 29502               NaN    NaN     NaN   NaN   NaN          NaN         NaN
# 35586               NaN    NaN     NaN   NaN   NaN          NaN         NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Nan이 많은 세 행 제거

# %%
data=data.drop([19729, 29502, 35586])

# %%
data[pd.isnull(data["vote_count"])==True]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, id, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### original_language 다시 정리

# %%
data["original_language"].describe()
# Out:
# count     45410
# unique       89
# top          en
# freq      32244
# Name: original_language, dtype: object

# %%
np.sum(pd.isnull(data["original_language"]))
# Out:
# 11

# %%
index = pd.isnull(data["original_language"])==True

# %%
data.loc[index,["original_language","original_title","production_countries","spoken_languages","title","release_date"]]
# Out:
#       original_language              original_title  \
# 19574               NaN     Shadowing the Third Man
# 21602               NaN              Unfinished Sky
# 22832               NaN             13 Fighting Men
# 32141               NaN                   Lambchops
# 37407               NaN                      Bajaja
# 41047               NaN              Song of Lahore
# 41872               NaN  Annabelle Serpentine Dance
# 44057               NaN       Lettre d'une inconnue
# 44410               NaN                        Garn
# 44576               NaN                      WiNWiN
# 44655               NaN       La prise de Tournavos
#
#                                     production_countries  \
# 19574  [Austria, France, Japan, United Kingdom, Unite...
# 21602                                        [Australia]
# 22832                         [United States of America]
# 32141                         [United States of America]
# 37407                                   [Czech Republic]
# 41047                                                NaN
# 41872                         [United States of America]
# 44057                                           [France]
# 44410                                                NaN
# 44576                                          [Austria]
# 44655                                           [France]
#
#                    spoken_languages                       title release_date
# 19574            [Deutsch, English]     Shadowing the Third Man   2004-10-11
# 21602                     [English]              Unfinished Sky   2007-08-04
# 22832                     [English]             13 Fighting Men   1960-03-31
# 32141                     [English]                   Lambchops   1929-10-31
# 37407                       [Český]               Prince Bayaya   1950-01-26
# 41047       [اردو, English, ਪੰਜਾਬੀ]              Song of Lahore   2015-11-13
# 41872                 [No Language]  Annabelle Serpentine Dance   1895-04-01
# 44057                    [Français]       Lettre d'une inconnue   2001-01-01
# 44410  [svenska, English, Íslenska]                        Yarn   2016-03-12
# 44576            [Deutsch, English]                      WiNWiN   2016-01-27
# 44655                 [No Language]  The Surrender of Tournavos   1897-01-01

# %%
data.loc[[19574,21602,22832,32141,41047,41872,44576,44655],"original_language"]="en"

# %%
data.loc[37407,"original_language"]="cs"

# %%
data.loc[44057,"original_language"]="fr"

# %%
data.loc[44410,"original_language"]="sv"

# %%
data.loc[index,["original_language","original_title","production_countries","spoken_languages","title","release_date"]]
# Out:
#       original_language              original_title  \
# 19574                en     Shadowing the Third Man
# 21602                en              Unfinished Sky
# 22832                en             13 Fighting Men
# 32141                en                   Lambchops
# 37407                cs                      Bajaja
# 41047                en              Song of Lahore
# 41872                en  Annabelle Serpentine Dance
# 44057                fr       Lettre d'une inconnue
# 44410                sv                        Garn
# 44576                en                      WiNWiN
# 44655                en       La prise de Tournavos
#
#                                     production_countries  \
# 19574  [Austria, France, Japan, United Kingdom, Unite...
# 21602                                        [Australia]
# 22832                         [United States of America]
# 32141                         [United States of America]
# 37407                                   [Czech Republic]
# 41047                                                NaN
# 41872                         [United States of America]
# 44057                                           [France]
# 44410                                                NaN
# 44576                                          [Austria]
# 44655                                           [France]
#
#                    spoken_languages                       title release_date
# 19574            [Deutsch, English]     Shadowing the Third Man   2004-10-11
# 21602                     [English]              Unfinished Sky   2007-08-04
# 22832                     [English]             13 Fighting Men   1960-03-31
# 32141                     [English]                   Lambchops   1929-10-31
# 37407                       [Český]               Prince Bayaya   1950-01-26
# 41047       [اردو, English, ਪੰਜਾਬੀ]              Song of Lahore   2015-11-13
# 41872                 [No Language]  Annabelle Serpentine Dance   1895-04-01
# 44057                    [Français]       Lettre d'une inconnue   2001-01-01
# 44410  [svenska, English, Íslenska]                        Yarn   2016-03-12
# 44576            [Deutsch, English]                      WiNWiN   2016-01-27
# 44655                 [No Language]  The Surrender of Tournavos   1897-01-01

# %%
#############################
###Demographic recommender###
#############################
####Using Weighted Rating###

# %%
data.head(3)
# Out:
#    adult      belongs_to_collection    budget                        genres  \
# 0  False       Toy Story Collection  30000000   [Animation, Comedy, Family]
# 1  False                        NaN  65000000  [Adventure, Fantasy, Family]
# 2  False  Grumpy Old Men Collection         0             [Romance, Comedy]
#
#       id original_language    original_title  \
# 0    862                en         Toy Story
# 1   8844                en           Jumanji
# 2  15602                en  Grumpier Old Men
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
#
#                                 production_companies  ... release_date  \
# 0                          [Pixar Animation Studios]  ...   1995-10-30
# 1  [TriStar Pictures, Teitler Film, Interscope Co...  ...   1995-12-15
# 2                     [Warner Bros., Lancaster Gate]  ...   1995-12-22
#
#        revenue  runtime     spoken_languages    status  \
# 0  373554033.0     81.0            [English]  Released
# 1  262797249.0    104.0  [English, Français]  Released
# 2          0.0    101.0            [English]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average  vote_count
# 0          7.7      5415.0
# 1          6.9      2413.0
# 2          6.5        92.0
#
# [3 rows x 21 columns]

# %%
m=data['vote_count'].quantile(q=0.9)

# %%
data_filtered = data[data['vote_count']>m]

# %%
data_filtered.shape
# Out:
# (4534, 21)

# %%
data['vote_count'].astype('int')
# Out:
# 0        5415
# 1        2413
# 2          92
# 3          34
# 4         173
#          ...
# 45461       1
# 45462       3
# 45463       6
# 45464       0
# 45465       0
# Name: vote_count, Length: 45421, dtype: int32

# %%
def movie_score(x):
    v=x['vote_count']
    m=data['vote_count'].quantile(q=0.9)
    R=x['vote_average']
    C=data['vote_average'].mean()
    return ((R*v)/(v+m))+((C*m)/(v+m))

# %%
data_filtered['score']=movie_score(data_filtered)
# Out:
# C:\Users\user\.conda\envs\test\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
highscore = data_filtered.sort_values(by='score', ascending=False).head(10)

# %%
highscore[['title', 'vote_count', 'vote_average', 'popularity', 'score']]
# Out:
#                              title  vote_count  vote_average  popularity  \
# 314       The Shawshank Redemption      8358.0           8.5   51.645403
# 834                  The Godfather      6024.0           8.5   41.109264
# 10309  Dilwale Dulhania Le Jayenge       661.0           9.1   34.457024
# 12481              The Dark Knight     12269.0           8.3  123.167259
# 2843                    Fight Club      9678.0           8.3   63.869599
# 292                   Pulp Fiction      8670.0           8.3  140.950236
# 522               Schindler's List      4436.0           8.3   41.725123
# 23673                     Whiplash      4376.0           8.3   64.299990
# 5481                 Spirited Away      3968.0           8.3   41.048867
# 2211             Life Is Beautiful      3643.0           8.3   39.394970
#
#           score
# 314    8.445878
# 834    8.425451
# 10309  8.421543
# 12481  8.265483
# 2843   8.256392
# 292    8.251414
# 522    8.206655
# 23673  8.205420
# 5481   8.196072
# 2211   8.187191

# %%
data_popular = data.sort_values('popularity', ascending=False)

# %%
data_popular[['title', 'vote_count', 'vote_average', 'popularity']].head(10)
# Out:
#                                 title  vote_count  vote_average  popularity
# 30700                         Minions      4729.0           6.4  547.488298
# 33356                    Wonder Woman      5025.0           7.2  294.337037
# 42222            Beauty and the Beast      5530.0           6.8  287.253654
# 43644                     Baby Driver      2083.0           7.2  228.032744
# 24455                      Big Hero 6      6289.0           7.8  213.849907
# 26564                        Deadpool     11444.0           7.4  187.860492
# 26566  Guardians of the Galaxy Vol. 2      4858.0           7.6  185.330992
# 14551                          Avatar     12114.0           7.2  185.070892
# 24351                       John Wick      5499.0           7.0  183.870374
# 23675                       Gone Girl      6023.0           7.9  154.801009

# %% [markdown]
# # (+) Credits.csv

# %%
cred = pd.read_csv('credits.csv')

# %%
cred["id"].describe()
# Out:
# count     45476.000000
# mean     108345.997537
# std      112443.796536
# min           2.000000
# 25%       26443.250000
# 50%       60002.500000
# 75%      157302.000000
# max      469172.000000
# Name: id, dtype: float64

# %%
cred["id"]=pd.to_numeric(cred["id"],errors='coerce')

# %%
pd.value_counts(cred["id"])
# Out:
# 141971    3
# 187156    2
# 152795    2
# 99080     2
# 24026     2
#          ..
# 19164     1
# 29403     1
# 31450     1
# 25305     1
# 276895    1
# Name: id, Length: 45432, dtype: int64

# %%
cred=cred.drop_duplicates(["id"],keep="first")

# %%
np.sum(cred.duplicated(["id"]))
# Out:
# 0

# %%
mc = pd.merge(cred, data, on='id')

# %%
mc.head(2)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
#
#                                                 crew    id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...   862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...  8844  False
#
#   belongs_to_collection    budget                        genres  \
# 0  Toy Story Collection  30000000   [Animation, Comedy, Family]
# 1                   NaN  65000000  [Adventure, Fantasy, Family]
#
#   original_language original_title  \
# 0                en      Toy Story
# 1                en        Jumanji
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
#
#        revenue runtime     spoken_languages    status  \
# 0  373554033.0    81.0            [English]  Released
# 1  262797249.0   104.0  [English, Français]  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 23 columns]

# %% [markdown]
# 컨텐츠 기반 분석 예측

# %%
mc['overview'].head()
# Out:
# 0    Led by Woody, Andy's toys live happily in his ...
# 1    When siblings Judy and Peter discover an encha...
# 2    A family wedding reignites the ancient feud be...
# 3    Cheated on, mistreated and stepped on, the wom...
# 4    Just when George Banks has recovered from his ...
# Name: overview, dtype: object

# %% [markdown]
# NaN을 공백으로 바꾸기

# %%
mc['overview'].isnull().sum()
# Out:
# 954

# %%
mc['overview'].fillna(' ', inplace=True)

# %% [markdown]
# TF-IDF Matrix 만들기

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# 램크기가 작아서 오류가 뜨는데 일단은 그냥 함
tfidfv = TfidfVectorizer(analyzer='word', stop_words='english')
tfidfv_matrix = tfidfv.fit_transform(mc['overview'])
tfidfv_matrix.todense().shape
# Out:
# (45420, 75824)

# %% [markdown]
# (45420, 75824) => 45420개의 영화를 설명하기 위해 75824개의 단어들이 사용되었다는 것을 알 수 있다.

# %% [markdown]
# Similarity Score 계산하기 -> 유사한 영화들을 추측할 수 있음

# %%
cosine_sim1 = linear_kernel(tfidfv_matrix, tfidfv_matrix)
cosine_sim1.shape 
#이것도 램크기가 작아서 그런데, 어쨌든 (45420, 45420)의 정방형 코사인 similarity matrix가 완성됨

# %% [markdown]
# 영화 제목 입력하면 비슷한 영화 10개 추측

# %%
indices=pd.Series(data=list(mc.index), index= mc['title'] )

# %%
indices.head()
# Out:
# title
# Toy Story                      0
# Jumanji                        1
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    4
# dtype: int64

# %%
# 영화 제목을 넣으면 비슷한 10개의 영화들을 예측(추천)하는 방식의 함수
def content_recommendations(title, cosine_sim):
    
    # 영화제목에 해당하는 인덱스를 설정
    idx = indices[title]
    
    # Pairwsie similarity scores 구하기
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # similarity scores로 영화 sort!
    sim_scores.sort(key=lambda x: x[1], reverse=True)

    # 비슷한 영화 10개 점수 구하기
    sim_scores=sim_scores[1:11]
    
    # 영화 인덱스 찾고
    ind=[]
    for (x,y) in sim_scores:
        ind.append(x)
        
    # Top 10 
    tit=[]
    for x in ind:
        tit.append(mc.iloc[x]['title'])
    return pd.Series(data=tit, index=ind)

# %%
mc['title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45415                         Subdue
# 45416            Century of Birthing
# 45417                       Betrayal
# 45418               Satan Triumphant
# 45419                       Queerama
# Name: title, Length: 45420, dtype: object

# %%
content_recommendations("Father of the Bride Part II", cosine_sim1)
# Out:
# 6792        Father of the Bride
# 6570                      Kuffs
# 6305            North to Alaska
# 19790                   Babbitt
# 34435         You're Killing Me
# 13606       The Magic of Méliès
# 5004                    Wendigo
# 27953          I Start Counting
# 43844    George of the Jungle 2
# 7096         The Out of Towners
# dtype: object

# %%
content_recommendations('Grumpier Old Men',cosine_sim1)
# Out:
# 9205     An Extremely Goofy Movie
# 35544                         Max
# 443                      Fearless
# 235                 A Goofy Movie
# 4100                Heartbreakers
# 24557               The Guardians
# 31678        The Phantom of Paris
# 1616                         Bent
# 2281                     Rushmore
# 35273            The Zohar Secret
# dtype: object

# %% [markdown]
# ♣ 심화적으로 영화 감독, 캐스팅, 장르에 기반한 분석을 추가한다.

# %% [markdown]
# Cast 전처리

# %%
mc['cast']
# Out:
# 0        [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1        [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2        [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3        [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4        [{'cast_id': 1, 'character': 'George Banks', '...
#                                ...
# 45415    [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45416    [{'cast_id': 1002, 'character': 'Sister Angela...
# 45417    [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45418    [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45419                                                   []
# Name: cast, Length: 45420, dtype: object

# %%
cast = []
for string in mc['cast']:
    cast_list = eval(str(string))
    if type(string)==float:
        cast.append(float('Nan'))
    else:
        cast2 = []
        for cast_dict in cast_list:
            cast_name = cast_dict["name"]
            cast2.append(cast_name)
        cast.append(cast2)

# %%
mc['cast'] = cast

# %%
mc['cast']
# Out:
# 0        [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1        [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2        [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3        [Whitney Houston, Angela Bassett, Loretta Devi...
# 4        [Steve Martin, Diane Keaton, Martin Short, Kim...
#                                ...
# 45415          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 45416    [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45417    [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45418    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45419                                                   []
# Name: cast, Length: 45420, dtype: object

# %% [markdown]
# Crew 전처리

# %%
mc[mc['crew']=='[]'].index
# Out:
# Int64Index([  189,   614,   635,   661,   711,   863,  1107,  1272,  1393,
#              1405,
#             ...
#             45031, 45041, 45076, 45103, 45115, 45181, 45206, 45221, 45292,
#             45315],
#            dtype='int64', length=770)

# %%
type(mc['crew'][189])
# Out:
# str

# %%
mc['crew'] = mc['crew'].astype('str')

# %%
eval(mc['crew'][0])
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Director',
#   'name': 'John Lasseter',
#   'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f4f',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12891,
#   'job': 'Screenplay',
#   'name': 'Joss Whedon',
#   'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f55',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7,
#   'job': 'Screenplay',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f5b',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12892,
#   'job': 'Screenplay',
#   'name': 'Joel Cohen',
#   'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f61',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 12893,
#   'job': 'Screenplay',
#   'name': 'Alec Sokolow',
#   'profile_path': '/v79vlRYi94BZUQnkkyznbGUZLjT.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f67',
#   'department': 'Production',
#   'gender': 1,
#   'id': 12894,
#   'job': 'Producer',
#   'name': 'Bonnie Arnold',
#   'profile_path': None},
#  {'credit_id': '52fe4284c3a36847f8024f6d',
#   'department': 'Production',
#   'gender': 0,
#   'id': 12895,
#   'job': 'Executive Producer',
#   'name': 'Ed Catmull',
#   'profile_path': None},
#  {'credit_id': '52fe4284c3a36847f8024f73',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12896,
#   'job': 'Producer',
#   'name': 'Ralph Guggenheim',
#   'profile_path': None},
#  {'credit_id': '52fe4284c3a36847f8024f79',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12897,
#   'job': 'Executive Producer',
#   'name': 'Steve Jobs',
#   'profile_path': '/mOMP3SwD5qWQSR0ldCIByd3guTV.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f8b',
#   'department': 'Editing',
#   'gender': 2,
#   'id': 8,
#   'job': 'Editor',
#   'name': 'Lee Unkrich',
#   'profile_path': '/bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f91',
#   'department': 'Art',
#   'gender': 2,
#   'id': 7883,
#   'job': 'Art Direction',
#   'name': 'Ralph Eggleston',
#   'profile_path': '/uUfcGKDsKO1aROMpXRs67Hn6RvR.jpg'},
#  {'credit_id': '598331bf925141421201044b',
#   'department': 'Editing',
#   'gender': 2,
#   'id': 1168870,
#   'job': 'Editor',
#   'name': 'Robert Gordon',
#   'profile_path': None},
#  {'credit_id': '5892168cc3a36809660095f9',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1552883,
#   'job': 'Foley Editor',
#   'name': 'Mary Helen Leasman',
#   'profile_path': None},
#  {'credit_id': '5531824d9251415289000945',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1453514,
#   'job': 'Animation',
#   'name': 'Kim Blanchette',
#   'profile_path': None},
#  {'credit_id': '589215969251412dcb009bf6',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1414182,
#   'job': 'ADR Editor',
#   'name': 'Marilyn McCoppen',
#   'profile_path': None},
#  {'credit_id': '589217099251412dc500a018',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 7885,
#   'job': 'Orchestrator',
#   'name': 'Randy Newman',
#   'profile_path': '/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg'},
#  {'credit_id': '5693e6b29251417b0e0000e3',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1429549,
#   'job': 'Color Timer',
#   'name': 'Dale E. Grahn',
#   'profile_path': None},
#  {'credit_id': '572e2522c3a36869e6001a9c',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 7949,
#   'job': 'CG Painter',
#   'name': 'Robin Cooper',
#   'profile_path': None},
#  {'credit_id': '574f12309251415ca1000012',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Original Story',
#   'name': 'John Lasseter',
#   'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'},
#  {'credit_id': '574f1240c3a3682e7300001c',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12890,
#   'job': 'Original Story',
#   'name': 'Pete Docter',
#   'profile_path': '/r6ngPgnReA3RHmKjmSoVsc6Awjp.jpg'},
#  {'credit_id': '574f12519251415c92000015',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 7911,
#   'job': 'Original Story',
#   'name': 'Joe Ranft',
#   'profile_path': '/f1BoWC2JbCcfP1e5hKfGsxkHzVU.jpg'},
#  {'credit_id': '574f12cec3a3682e82000022',
#   'department': 'Crew',
#   'gender': 0,
#   'id': 1629419,
#   'job': 'Post Production Supervisor',
#   'name': 'Patsy Bouge',
#   'profile_path': None},
#  {'credit_id': '574f14f19251415ca1000082',
#   'department': 'Art',
#   'gender': 0,
#   'id': 7961,
#   'job': 'Sculptor',
#   'name': 'Norm DeCarlo',
#   'profile_path': None},
#  {'credit_id': '5751ae4bc3a3683772002b7f',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 12905,
#   'job': 'Animation Director',
#   'name': 'Ash Brannon',
#   'profile_path': '/6ueWgPEEBHvS3De2BHYQnYjRTig.jpg'},
#  {'credit_id': '5891edbe9251412dc5007cd6',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 7885,
#   'job': 'Music',
#   'name': 'Randy Newman',
#   'profile_path': '/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg'},
#  {'credit_id': '589213d39251412dc8009832',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1748707,
#   'job': 'Layout',
#   'name': 'Roman Figun',
#   'profile_path': None},
#  {'credit_id': '5892173dc3a3680968009351',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 4949,
#   'job': 'Orchestrator',
#   'name': 'Don Davis',
#   'profile_path': None},
#  {'credit_id': '589217cec3a3686b0a0052ba',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1372885,
#   'job': 'Music Editor',
#   'name': 'James Flamberg',
#   'profile_path': None},
#  {'credit_id': '58921831c3a3686348004a64',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1739962,
#   'job': 'Negative Cutter',
#   'name': 'Mary Beth Smith',
#   'profile_path': None},
#  {'credit_id': '58921838c3a36809700096c0',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1748513,
#   'job': 'Negative Cutter',
#   'name': 'Rick Mackay',
#   'profile_path': None},
#  {'credit_id': '589218429251412dd1009d1b',
#   'department': 'Art',
#   'gender': 0,
#   'id': 1458006,
#   'job': 'Title Designer',
#   'name': 'Susan Bradley',
#   'profile_path': None},
#  {'credit_id': '5891ed99c3a3680966007670',
#   'department': 'Crew',
#   'gender': 0,
#   'id': 1748557,
#   'job': 'Supervising Technical Director',
#   'name': 'William Reeves',
#   'profile_path': None},
#  {'credit_id': '5891edcec3a3686b0a002eb2',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 7885,
#   'job': 'Songs',
#   'name': 'Randy Newman',
#   'profile_path': '/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg'},
#  {'credit_id': '5891edf9c3a36809700075e6',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7,
#   'job': 'Original Story',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '58920f0b9251412dd7009104',
#   'department': 'Crew',
#   'gender': 2,
#   'id': 12890,
#   'job': 'Supervising Animator',
#   'name': 'Pete Docter',
#   'profile_path': '/r6ngPgnReA3RHmKjmSoVsc6Awjp.jpg'},
#  {'credit_id': '58920f1fc3a3680977009021',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 2216,
#   'job': 'Sound Designer',
#   'name': 'Gary Rydstrom',
#   'profile_path': '/jZpr1nVfO7lldWI0YtmP1FGw7Rj.jpg'},
#  {'credit_id': '58920f389251412dd700912d',
#   'department': 'Production',
#   'gender': 0,
#   'id': 12909,
#   'job': 'Production Supervisor',
#   'name': 'Karen Robert Jackson',
#   'profile_path': None},
#  {'credit_id': '58920fbd9251412dcb00969c',
#   'department': 'Crew',
#   'gender': 0,
#   'id': 953331,
#   'job': 'Executive Music Producer',
#   'name': 'Chris Montan',
#   'profile_path': None},
#  {'credit_id': '589210069251412dd7009219',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 7893,
#   'job': 'Animation Director',
#   'name': 'Rich Quade',
#   'profile_path': None},
#  {'credit_id': '589210329251412dcd00943b',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8025,
#   'job': 'Animation',
#   'name': 'Michael Berenstein',
#   'profile_path': None},
#  {'credit_id': '5892103bc3a368096a009180',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 78009,
#   'job': 'Animation',
#   'name': 'Colin Brady',
#   'profile_path': None},
#  {'credit_id': '5892105dc3a3680968008db2',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748682,
#   'job': 'Animation',
#   'name': 'Davey Crockett Feiten',
#   'profile_path': None},
#  {'credit_id': '589210669251412dcd009466',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1454030,
#   'job': 'Animation',
#   'name': 'Angie Glocka',
#   'profile_path': None},
#  {'credit_id': '5892107c9251412dd1009613',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748683,
#   'job': 'Animation',
#   'name': 'Rex Grignon',
#   'profile_path': None},
#  {'credit_id': '5892108ac3a3680973008d3f',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748684,
#   'job': 'Animation',
#   'name': 'Tom K. Gurney',
#   'profile_path': None},
#  {'credit_id': '58921093c3a3686348004477',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 8029,
#   'job': 'Animation',
#   'name': 'Jimmy Hayward',
#   'profile_path': '/lTDRpudEY7BDwTefXbXzMlmb0ui.jpg'},
#  {'credit_id': '5892109b9251412dcd0094b0',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1426773,
#   'job': 'Animation',
#   'name': 'Hal T. Hickel',
#   'profile_path': None},
#  {'credit_id': '589210a29251412dc5009a29',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8035,
#   'job': 'Animation',
#   'name': 'Karen Kiser',
#   'profile_path': None},
#  {'credit_id': '589210ccc3a3680977009191',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748688,
#   'job': 'Animation',
#   'name': 'Anthony B. LaMolinara',
#   'profile_path': None},
#  {'credit_id': '589210d7c3a3686b0a004c1f',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 587314,
#   'job': 'Animation',
#   'name': 'Guionne Leroy',
#   'profile_path': None},
#  {'credit_id': '589210e1c3a36809770091a7',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7918,
#   'job': 'Animation',
#   'name': 'Bud Luckey',
#   'profile_path': '/pcCh7G19FKMNijmPQg1PMH1btic.jpg'},
#  {'credit_id': '589210ee9251412dc200978a',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748689,
#   'job': 'Animation',
#   'name': 'Les Major',
#   'profile_path': None},
#  {'credit_id': '589210fa9251412dc8009595',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7892,
#   'job': 'Animation',
#   'name': 'Glenn McQueen',
#   'profile_path': None},
#  {'credit_id': '589211029251412dc8009598',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 555795,
#   'job': 'Animation',
#   'name': 'Mark Oftedal',
#   'profile_path': None},
#  {'credit_id': '5892110b9251412dc800959d',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7882,
#   'job': 'Animation',
#   'name': 'Jeff Pidgeon',
#   'profile_path': '/yLddkg5HcgbJg00cS13GVBnP0HY.jpg'},
#  {'credit_id': '58921113c3a36863480044e4',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8017,
#   'job': 'Animation',
#   'name': 'Jeff Pratt',
#   'profile_path': None},
#  {'credit_id': '5892111c9251412dcb0097e9',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1184140,
#   'job': 'Animation',
#   'name': 'Steve Rabatich',
#   'profile_path': None},
#  {'credit_id': '58921123c3a36809700090f6',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8049,
#   'job': 'Animation',
#   'name': 'Roger Rose',
#   'profile_path': None},
#  {'credit_id': '5892112b9251412dcb0097fb',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1509559,
#   'job': 'Animation',
#   'name': 'Steve Segal',
#   'profile_path': None},
#  {'credit_id': '589211349251412dc80095c3',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748691,
#   'job': 'Animation',
#   'name': 'Doug Sheppeck',
#   'profile_path': None},
#  {'credit_id': '5892113cc3a3680970009106',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8050,
#   'job': 'Animation',
#   'name': 'Alan Sperling',
#   'profile_path': None},
#  {'credit_id': '58921148c3a3686b0a004c99',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8010,
#   'job': 'Animation',
#   'name': 'Doug Sweetland',
#   'profile_path': None},
#  {'credit_id': '58921150c3a3680966009125',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8044,
#   'job': 'Animation',
#   'name': 'David Tart',
#   'profile_path': None},
#  {'credit_id': '589211629251412dc5009b00',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1454034,
#   'job': 'Animation',
#   'name': 'Ken Willard',
#   'profile_path': None},
#  {'credit_id': '589211c1c3a3686b0a004d28',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 7887,
#   'job': 'Visual Effects Supervisor',
#   'name': 'Thomas Porter',
#   'profile_path': None},
#  {'credit_id': '589211d4c3a3680968008ed9',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1406878,
#   'job': 'Visual Effects',
#   'name': 'Mark Thomas Henne',
#   'profile_path': None},
#  {'credit_id': '589211f59251412dd4008e65',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748698,
#   'job': 'Visual Effects',
#   'name': 'Oren Jacob',
#   'profile_path': None},
#  {'credit_id': '58921242c3a368096a00939b',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748699,
#   'job': 'Visual Effects',
#   'name': 'Darwyn Peachey',
#   'profile_path': None},
#  {'credit_id': '5892124b9251412dc5009bd2',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748701,
#   'job': 'Visual Effects',
#   'name': 'Mitch Prater',
#   'profile_path': None},
#  {'credit_id': '58921264c3a3686b0a004dbf',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748703,
#   'job': 'Visual Effects',
#   'name': 'Brian M. Rosen',
#   'profile_path': None},
#  {'credit_id': '589212709251412dcd009676',
#   'department': 'Lighting',
#   'gender': 1,
#   'id': 12912,
#   'job': 'Lighting Supervisor',
#   'name': 'Sharon Calahan',
#   'profile_path': None},
#  {'credit_id': '5892127fc3a3686b0a004de5',
#   'department': 'Lighting',
#   'gender': 0,
#   'id': 7899,
#   'job': 'Lighting Supervisor',
#   'name': 'Galyn Susman',
#   'profile_path': None},
#  {'credit_id': '589212cdc3a3680970009268',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 12915,
#   'job': 'CG Painter',
#   'name': 'William Cone',
#   'profile_path': None},
#  {'credit_id': '5892130f9251412dc8009791',
#   'department': 'Art',
#   'gender': 0,
#   'id': 1748705,
#   'job': 'Sculptor',
#   'name': 'Shelley Daniels Lekven',
#   'profile_path': None},
#  {'credit_id': '5892131c9251412dd4008f4c',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7889,
#   'job': 'Character Designer',
#   'name': 'Bob Pauley',
#   'profile_path': None},
#  {'credit_id': '589213249251412dd100987b',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7918,
#   'job': 'Character Designer',
#   'name': 'Bud Luckey',
#   'profile_path': '/pcCh7G19FKMNijmPQg1PMH1btic.jpg'},
#  {'credit_id': '5892132b9251412dc80097b1',
#   'department': 'Visual Effects',
#   'gender': 2,
#   'id': 7,
#   'job': 'Character Designer',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '58921332c3a368634800467b',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 12915,
#   'job': 'Character Designer',
#   'name': 'William Cone',
#   'profile_path': None},
#  {'credit_id': '5892135f9251412dd4008f90',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1748706,
#   'job': 'Character Designer',
#   'name': 'Steve Johnson',
#   'profile_path': None},
#  {'credit_id': '58921384c3a3680973008fd4',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1176752,
#   'job': 'Character Designer',
#   'name': 'Dan Haskett',
#   'profile_path': None},
#  {'credit_id': '5892138e9251412dc20099fc',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1088034,
#   'job': 'Character Designer',
#   'name': 'Tom Holloway',
#   'profile_path': '/a0r0T2usTBpgMI5aZbRBDW1fTl8.jpg'},
#  {'credit_id': '58921395c3a368097700942f',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 1447465,
#   'job': 'Character Designer',
#   'name': 'Jean Gillmore',
#   'profile_path': None},
#  {'credit_id': '589213e2c3a3680973009026',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1748709,
#   'job': 'Layout',
#   'name': 'Desirée Mourad',
#   'profile_path': None},
#  {'credit_id': '589214099251412dc5009d57',
#   'department': 'Art',
#   'gender': 0,
#   'id': 1748710,
#   'job': 'Set Dresser',
#   'name': "Kelly O'Connell",
#   'profile_path': None},
#  {'credit_id': '58921411c3a3686b0a004f70',
#   'department': 'Art',
#   'gender': 0,
#   'id': 1443471,
#   'job': 'Set Dresser',
#   'name': 'Sonoko Konishi',
#   'profile_path': None},
#  {'credit_id': '58921434c3a368096a00956e',
#   'department': 'Art',
#   'gender': 0,
#   'id': 1748711,
#   'job': 'Set Dresser',
#   'name': 'Ann M. Rockwell',
#   'profile_path': None},
#  {'credit_id': '5892144ac3a36809680090de',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1748712,
#   'job': 'Editorial Manager',
#   'name': 'Julie M. McDonald',
#   'profile_path': None},
#  {'credit_id': '58921479c3a368096800910f',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1589729,
#   'job': 'Assistant Editor',
#   'name': 'Robin Lee',
#   'profile_path': None},
#  {'credit_id': '5892148b9251412dd10099cc',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1748716,
#   'job': 'Assistant Editor',
#   'name': 'Tom Freeman',
#   'profile_path': None},
#  {'credit_id': '589214959251412dcb009b1f',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1748717,
#   'job': 'Assistant Editor',
#   'name': 'Ada Cochavi',
#   'profile_path': None},
#  {'credit_id': '5892149ec3a3686348004798',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1336438,
#   'job': 'Assistant Editor',
#   'name': 'Dana Mulligan',
#   'profile_path': None},
#  {'credit_id': '589214adc3a368096a0095db',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1748718,
#   'job': 'Editorial Coordinator',
#   'name': 'Deirdre Morrison',
#   'profile_path': None},
#  {'credit_id': '589214c7c3a368097700952b',
#   'department': 'Production',
#   'gender': 0,
#   'id': 1748719,
#   'job': 'Production Coordinator',
#   'name': 'Lori Lombardo',
#   'profile_path': None},
#  {'credit_id': '589214cec3a368096a009603',
#   'department': 'Production',
#   'gender': 0,
#   'id': 1748720,
#   'job': 'Production Coordinator',
#   'name': 'Ellen Devine',
#   'profile_path': None},
#  {'credit_id': '589214e39251412dc8009904',
#   'department': 'Crew',
#   'gender': 0,
#   'id': 1468014,
#   'job': 'Unit Publicist',
#   'name': 'Lauren Beth Strogoff',
#   'profile_path': None},
#  {'credit_id': '58921544c3a3686b0a00507d',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 2216,
#   'job': 'Sound Re-Recording Mixer',
#   'name': 'Gary Rydstrom',
#   'profile_path': '/jZpr1nVfO7lldWI0YtmP1FGw7Rj.jpg'},
#  {'credit_id': '5892154c9251412dd1009a56',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1425978,
#   'job': 'Sound Re-Recording Mixer',
#   'name': 'Gary Summers',
#   'profile_path': None},
#  {'credit_id': '58921555c3a36809680091bd',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 8276,
#   'job': 'Supervising Sound Editor',
#   'name': 'Tim Holland',
#   'profile_path': None},
#  {'credit_id': '589215c39251412dcb009c12',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 7069,
#   'job': 'Sound Effects Editor',
#   'name': 'Pat Jackson',
#   'profile_path': None},
#  {'credit_id': '58921698c3a368096a009788',
#   'department': 'Crew',
#   'gender': 2,
#   'id': 15894,
#   'job': 'Sound Design Assistant',
#   'name': 'Tom Myers',
#   'profile_path': None},
#  {'credit_id': '589216a89251412dc2009ca4',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1414177,
#   'job': 'Assistant Sound Editor',
#   'name': 'J.R. Grubbs',
#   'profile_path': None},
#  {'credit_id': '589216c19251412dc2009cb9',
#   'department': 'Sound',
#   'gender': 1,
#   'id': 1748724,
#   'job': 'Assistant Sound Editor',
#   'name': 'Susan Sanford',
#   'profile_path': None},
#  {'credit_id': '589216ccc3a3680973009274',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 1748725,
#   'job': 'Assistant Sound Editor',
#   'name': 'Susan Popovic',
#   'profile_path': None},
#  {'credit_id': '589216d79251412dc8009aa0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 8067,
#   'job': 'Assistant Sound Editor',
#   'name': 'Dan Engstrom',
#   'profile_path': None},
#  {'credit_id': '589216e49251412dcd009a4f',
#   'department': 'Production',
#   'gender': 1,
#   'id': 7902,
#   'job': 'Casting Consultant',
#   'name': 'Ruth Lambert',
#   'profile_path': None},
#  {'credit_id': '589216f39251412dc2009cf3',
#   'department': 'Production',
#   'gender': 0,
#   'id': 84493,
#   'job': 'ADR Voice Casting',
#   'name': 'Mickie McGowan',
#   'profile_path': '/k7TjJBfINsg8vLQxJwos6XObAD6.jpg'}]

# %%
# crew에서 name만 리스트로 추출하는 과정
crew1 = []
for string in mc['crew']:
    crew_list = eval(string)
    if type(string)==float:
        crew1.append(float('Nan'))
    else:
        crew2 = []
        for crew_dict in crew_list:
            crew_name = crew_dict["name"]
            crew2.append(crew_name)
        crew1.append(crew2)

# %%
# float 때문에 iteration이 되지 않아서 작업해줌
mc["cast"].loc[mc["cast"].isnull()] = mc["cast"].loc[mc["cast"].isnull()].apply(lambda x:[])
mc["crew"].loc[mc["crew"].isnull()] = mc["crew"].loc[mc["crew"].isnull()].apply(lambda x:[])
mc["genres"].loc[mc["genres"].isnull()] = mc["genres"].loc[mc["genres"].isnull()].apply(lambda x:[])
# Out:
# C:\Users\user\.conda\envs\test\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
# name 중에서 director만 리스트로 추출하는 과정
crew = []
for i in range(len(crew1)):
    crew.append(' '.join(crew1[i][:1]))

# %%
mc['crew']= crew

# %%
# top3 actors를 추출하는 과정
actor= []
for i in range(len(mc['cast'])):
    actor.append(mc['cast'][i][:3])

# %%
# top3 genres를 추출하는 과정
genres= []
for i in range(len(mc['genres'])):
    genres.append(mc['genres'][i][:3])

# %%
mc['director'] = mc['crew']
mc['actor'] = actor
mc['genres'] = genres

# %%
mc[['title', 'actor', 'director', 'genres']].head(10)
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
# 5                         Heat
# 6                      Sabrina
# 7                 Tom and Huck
# 8                 Sudden Death
# 9                    GoldenEye
#
#                                                actor         director  \
# 0                [Tom Hanks, Tim Allen, Don Rickles]    John Lasseter
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]  Larry J. Franco
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]    Howard Deutch
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]  Forest Whitaker
# 4         [Steve Martin, Diane Keaton, Martin Short]   Alan Silvestri
# 5            [Al Pacino, Robert De Niro, Val Kilmer]     Michael Mann
# 6        [Harrison Ford, Julia Ormond, Greg Kinnear]   Sydney Pollack
# 7  [Jonathan Taylor Thomas, Brad Renfro, Rachael ...   David Loughery
# 8  [Jean-Claude Van Damme, Powers Boothe, Dorian ...      Peter Hyams
# 9     [Pierce Brosnan, Sean Bean, Izabella Scorupco]  Martin Campbell
#
#                           genres
# 0    [Animation, Comedy, Family]
# 1   [Adventure, Fantasy, Family]
# 2              [Romance, Comedy]
# 3       [Comedy, Drama, Romance]
# 4                       [Comedy]
# 5         [Action, Crime, Drama]
# 6              [Comedy, Romance]
# 7     [Action, Adventure, Drama]
# 8  [Action, Adventure, Thriller]
# 9  [Adventure, Action, Thriller]

# %% [markdown]
# 이름을 구분하기 위해 처리하는 과정 (lowercase와 공백제거 활용)

# %%
def clean_director(x):
    return x.lower().replace(' ','')

# %%
mc['director'] = mc['director'].apply(lambda x:clean_director(x))

# %%
actor2 = []
for i in range(len(mc['actor'])):
    actor3 = []
    for j in range(len(mc['actor'][i])):
        actor3.append(mc['actor'][i][j].lower().replace(' ', ''))
    actor2.append(actor3)

# %%
mc['actor'] = actor2

# %%
genres2 = []
for i in range(len(mc['genres'])):
    genres3 = []
    for j in range(len(mc['genres'][i])):
        genres3.append(mc['genres'][i][j].lower())
    genres2.append(genres3)

# %%
mc['genres'] = genres2

# %%
mc[['title', 'actor', 'director', 'genres']].head(5)
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             actor        director  \
# 0                [tomhanks, timallen, donrickles]    johnlasseter
# 1     [robinwilliams, jonathanhyde, kirstendunst]   larryj.franco
# 2        [waltermatthau, jacklemmon, ann-margret]    howarddeutch
# 3  [whitneyhouston, angelabassett, lorettadevine]  forestwhitaker
# 4         [stevemartin, dianekeaton, martinshort]   alansilvestri
#
#                          genres
# 0   [animation, comedy, family]
# 1  [adventure, fantasy, family]
# 2             [romance, comedy]
# 3      [comedy, drama, romance]
# 4                      [comedy]

# %% [markdown]
# soup열 생성

# %%
def create_soup(x):
    return ' '.join(x['actor']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])

# %%
mc['soup'] = mc.apply(create_soup, axis=1)

# %% [markdown]
# CountVectorizer() 생성

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(stop_words='english')
cv_matrix = cv.fit_transform(mc['soup'])

# %% [markdown]
# Similarity Score 계산

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim2 = cosine_similarity(cv_matrix, cv_matrix)

# %%
content_recommendations('The Dark Knight Rises', cosine_sim2)
# Out:
# 10119          Batman Begins
# 12477        The Dark Knight
# 516        Romeo Is Bleeding
# 2989               Backdraft
# 4021                Hannibal
# 9227                  Shiner
# 23876              Quicksand
# 24817               Deadfall
# 9783         Amongst Friends
# 276      Murder in the First
# dtype: object

# %%
content_recommendations('The Godfather', cosine_sim2)
# Out:
# 1178             The Godfather: Part II
# 1913            The Godfather: Part III
# 15432                   The Rain People
# 1165                     Apocalypse Now
# 2004                      The Outsiders
# 3984                   Gardens of Stone
# 5260                        The Gambler
# 7924     The Night of the Following Day
# 18742                         Last Exit
# 34242                              Rege
# dtype: object

# %% [markdown]
# 앞에서 사용했던 content_recommendation 함수를 활용하면 앞서 사용했던 similarity score보다 더 정교한 추천 및 예측을 할 수 있다.
